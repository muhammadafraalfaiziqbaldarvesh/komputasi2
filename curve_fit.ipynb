# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadafraalfaiziqbaldarvesh/komputasi2/blob/main/curve_fit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)
plt.scatter(x, y);

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit);

# %%
print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)
# Out:
# Model slope:     2.0272088103606953
# Model intercept: -4.998577085553204

# %%
# Prediksi berdasarkan model fitting
xfit = np.linspace(0, 10, 1000)
yfit = model_func(xfit, *params)

# Plot data asli dan hasil fitting
plt.scatter(x, y, label="Data Asli")
plt.plot(xfit, yfit, label="Fitted Curve", color="blue")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("Curve Fitting with Sinusoidal Model")
plt.show()
